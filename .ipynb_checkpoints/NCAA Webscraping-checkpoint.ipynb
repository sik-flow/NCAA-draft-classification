# %%
# !pip install beautifulsoup4

# %%
#Import moduels
import requests
from bs4 import BeautifulSoup as bs

# %%
#URL

URL = "https://en.wikipedia.org/wiki/List_of_NCAA_Division_I_men's_basketball_programs"
page = requests.get(URL)

# %%
# Print html content of the page
print(page.content)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of NCAA Division I men\'s basketball programs - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"b71961e3-938f-4631-bd5e-75c429ec4f2d","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_NCAA_Division_I_men\'s_basketball_programs","wgTitle":"List of NCAA Division I men\'s basketball programs","wgCurRevisionId":987164660,"wgRevisionId":987164660,"wgArticleId":39831490,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short descript
# ...

# %%
web = bs(page.content,'html.parser')

# %%
print(web)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of NCAA Division I men's basketball programs - Wikipedia</title>
# ...

# %%
#Finding Elements by class "wikitable sortable jquery-tablesorter"

wikitable = web.find('table',{'class':'wikitable sortable'})

# %%
print(wikitable)
# Out:
# <table class="wikitable sortable">
# <tbody><tr valign="baseline">
# <th>School
# </th>
# <th>Nickname
# </th>
# <th>Home arena
# </th>
# <th>Conference
# </th>
# <th>Tournament Appearances
# </th>
# <th>Final Four Appearances
# </th>
# <th>Championship Wins
# </th></tr>
# <tr>
# <td><span data-sort-value="Albany !"><a href="/wiki/University_at_Albany,_SUNY" title="University at Albany, SUNY">University at Albany, SUNY</a></span> (Albany or UAlbany)
# </td>
# <td><a href="/wiki/Albany_Great_Danes_men%27s_basketball" title="Albany Great Danes men's basketball">Great Danes</a>
# </td>
# <td><a href="/wiki/SEFCU_Arena" title="SEFCU Arena">SEFCU Arena</a>
# </td>
# <td><a href="/wiki/America_East_Conference" title="America East Conference">America East</a>
# </td>
# <td>(5) 2006, 2007, 2013, 2014, 2015
# </td>
# <td>(0)
# </td>
# <td>(0)
# </td></tr>
# <tr>
# ...

# %%
#find all table row
wikitable.find_all('tr')[1:]
# Out:
# [<tr>
#  <td><span data-sort-value="Albany !"><a href="/wiki/University_at_Albany,_SUNY" title="University at Albany, SUNY">University at Albany, SUNY</a></span> (Albany or UAlbany)
#  </td>
#  <td><a href="/wiki/Albany_Great_Danes_men%27s_basketball" title="Albany Great Danes men's basketball">Great Danes</a>
#  </td>
#  <td><a href="/wiki/SEFCU_Arena" title="SEFCU Arena">SEFCU Arena</a>
#  </td>
#  <td><a href="/wiki/America_East_Conference" title="America East Conference">America East</a>
#  </td>
#  <td>(5) 2006, 2007, 2013, 2014, 2015
#  </td>
#  <td>(0)
#  </td>
#  <td>(0)
#  </td></tr>,
#  <tr>
#  <td><span data-sort-value="Binghamton !"><a href="/wiki/Binghamton_University" title="Binghamton University">Binghamton University</a></span>
#  </td>
#  <td><a href="/wiki/Binghamton_Bearcats_men%27s_basketball" title="Binghamton Bearcats men's basketball">Bearcats</a>
#  </td>
# ...

# %%
#get all names of D1 colleges
college_names = []
for row in wikitable.find_all('tr')[1:]:
    college_names.append(row.find('a').text)

# %%
temp = []
for row in wikitable.find_all('tr')[1:]:
    for x in row.find_all('td'):
        temp.append(x.text.splitlines())

# %%
temp
# Out:
# [['University at Albany, SUNY (Albany or UAlbany)'],
#  ['Great Danes'],
#  ['SEFCU Arena'],
#  ['America East'],
#  ['(5) 2006, 2007, 2013, 2014, 2015'],
#  ['(0)'],
#  ['(0)'],
#  ['Binghamton University'],
#  ['Bearcats'],
#  ['Binghamton University Events Center'],
#  ['America East'],
#  ['(1) 2009'],
#  ['(0)'],
#  ['(0)'],
#  ['University of Hartford'],
#  ['Hawks'],
#  ['Chase Arena at Reich Family Pavilion'],
#  ['America East'],
#  ['(0)'],
#  ['(0)'],
#  ['(0)'],
#  ['University of Maine (alternately UMaine)'],
#  ['Black Bears'],
#  ['Alfond Arena'],
#  ['America East'],
#  ['(0)'],
#  ['(0)'],
#  ['(0)'],
#  ['University of Maryland, Baltimore County (UMBC)'],
#  ['Retrievers'],
#  ['Retriever Activities Center'],
#  ['America East'],
#  ['(2) 2008, 2018'],
#  ['(0)'],
#  ['(0)'],
#  ['University of Massachusetts Lowell (UMass Lowell)'],
#  ['River Hawks'],
#  ['Tsongas Center at UMass Lowell/Costello Athletic Center'],
#  ['America East'],
#  ['(0)'],
#  ['(0)'],
# ...

# %%
for ele in temp[::7]:
    print(ele)
# Out:
# ['University at Albany, SUNY (Albany or UAlbany)']
# ['Binghamton University']
# ['University of Hartford']
# ['University of Maine (alternately UMaine)']
# ['University of Maryland, Baltimore County (UMBC)']
# ['University of Massachusetts Lowell (UMass Lowell)']
# ['University of New Hampshire']
# ['New Jersey Institute of Technology (NJIT)']
# ['Stony Brook University']
# ['University of Vermont']
# ['University of Central Florida (UCF)']
# ['University of Cincinnati']
# ['East Carolina University']
# ['University of Houston']
# ['University of Memphis']
# ['University of South Florida (alternately USF)']
# ['Southern Methodist University (SMU)']
# ['Temple University']
# ['Tulane University']
# ['University of Tulsa']
# ['Wichita State University']
# ['Boston College']
# ['Clemson University']
# ['Duke University']
# ['Florida State University']
# ['Georgia Institute of Technology (Georgia Tech)']
# ['University of Louisville']
# ['University of Miami (often Miami (FL))']
# ...

# %%
temp[:7]
# Out:
# [['University at Albany, SUNY (Albany or UAlbany)'],
#  ['Great Danes'],
#  ['SEFCU Arena'],
#  ['America East'],
#  ['(5) 2006, 2007, 2013, 2014, 2015'],
#  ['(0)'],
#  ['(0)']]

# %%
dic = {}
dic['less'] = 'loww'

# %%
dic
# Out:
# {'less': 'loww'}

# %%
dic['less'] = 'kjkj'

# %%
dic
# Out:
# {'less': 'kjkj'}

# %% [markdown]
# ### Kaggle dataset

# %%
# Import libraries
import pandas as pd

# %%
# Import data

df = pd.read_csv('Data\')
